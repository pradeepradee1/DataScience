# %% [markdown]
# ## Time Series EDA

# %%
## Install Pandas Data Reader for data sets
# !pip install pandas-datareader
# !pip install yfinance
# !pip install fix-yahoo-finance

# %%
import yfinance as yfin
yfin.pdr_override()
import pandas_datareader as pdr
import pandas as pd
from datetime import datetime

# %%
pdr.__version__
# Out:
# '0.10.0'

# %%
import yfinance as yf 
df_tesla = yf.download('TSLA', start='2017-02-01', end='2022-02-24')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %% [markdown]
# ### Tesla Share Details

# %%
df_tesla
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-02-01   16.870001   16.879999   16.603333   16.615999   16.615999
# 2017-02-02   16.556000   16.827999   16.514000   16.770000   16.770000
# 2017-02-03   16.794001   16.812000   16.645332   16.755333   16.755333
# 2017-02-06   16.733334   17.188000   16.708668   17.184668   17.184668
# 2017-02-07   17.212667   17.333332   17.094667   17.165333   17.165333
# ...                ...         ...         ...         ...         ...
# 2022-02-16  304.683319  308.809998  300.403320  307.796661  307.796661
# 2022-02-17  304.420013  306.166656  291.366669  292.116669  292.116669
# 2022-02-18  295.333344  295.623322  279.203339  285.660004  285.660004
# 2022-02-22  278.043335  285.576660  267.033325  273.843323  273.843323
# 2022-02-23  276.809998  278.433319  253.520004  254.679993  254.679993
#
#               Volume
# Date
# 2017-02-01  59382000
# 2017-02-02  37497000
# 2017-02-03  32800500
# ...

# %%
df_tesla.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1275.000000  1275.000000  1275.000000  1275.000000  1275.000000
# mean     91.221871    93.233315    89.015852    91.211831    91.211831
# std     106.109359   108.474444   103.405594   106.009488   106.009488
# min      12.073333    12.445333    11.799333    11.931333    11.931333
# 25%      20.143333    20.513667    19.793333    20.192333    20.192333
# 50%      23.504667    23.812668    23.083332    23.454000    23.454000
# 75%     156.526665   166.023331   148.474998   160.281670   160.281670
# max     411.470001   414.496674   405.666656   409.970001   409.970001
#
#              Volume
# count  1.275000e+03
# mean   1.335287e+08
# std    9.008957e+07
# min    2.940180e+07
# 25%    7.547100e+07
# 50%    1.047960e+08
# 75%    1.561112e+08
# max    9.140820e+08

# %%
df_tesla.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-02-16  304.683319  308.809998  300.403320  307.796661  307.796661
# 2022-02-17  304.420013  306.166656  291.366669  292.116669  292.116669
# 2022-02-18  295.333344  295.623322  279.203339  285.660004  285.660004
# 2022-02-22  278.043335  285.576660  267.033325  273.843323  273.843323
# 2022-02-23  276.809998  278.433319  253.520004  254.679993  254.679993
#
#               Volume
# Date
# 2022-02-16  51294300
# 2022-02-17  55178400
# 2022-02-18  68501700
# 2022-02-22  83288100
# 2022-02-23  95256900

# %%
# a=list(df_tesla.index.astype(str).values)
# a.sort()
# print(a)

# %%
list(df_tesla.index.values.astype(str))
# Out:
# ['2017-02-01T00:00:00.000000000',
#  '2017-02-02T00:00:00.000000000',
#  '2017-02-03T00:00:00.000000000',
#  '2017-02-06T00:00:00.000000000',
#  '2017-02-07T00:00:00.000000000',
#  '2017-02-08T00:00:00.000000000',
#  '2017-02-09T00:00:00.000000000',
#  '2017-02-10T00:00:00.000000000',
#  '2017-02-13T00:00:00.000000000',
#  '2017-02-14T00:00:00.000000000',
#  '2017-02-15T00:00:00.000000000',
#  '2017-02-16T00:00:00.000000000',
#  '2017-02-17T00:00:00.000000000',
#  '2017-02-21T00:00:00.000000000',
#  '2017-02-22T00:00:00.000000000',
#  '2017-02-23T00:00:00.000000000',
#  '2017-02-24T00:00:00.000000000',
#  '2017-02-27T00:00:00.000000000',
#  '2017-02-28T00:00:00.000000000',
#  '2017-03-01T00:00:00.000000000',
#  '2017-03-02T00:00:00.000000000',
#  '2017-03-03T00:00:00.000000000',
#  '2017-03-06T00:00:00.000000000',
#  '2017-03-07T00:00:00.000000000',
#  '2017-03-08T00:00:00.000000000',
#  '2017-03-09T00:00:00.000000000',
#  '2017-03-10T00:00:00.000000000',
# ...

# %%
df_tesla['High'].plot(figsize=(12,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
## x limit and y limit
df_tesla['High'].plot(xlim=['2020-01-01','2021-09-01'],figsize=(12,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
## xlimit and y limit
df_tesla['High'].plot(xlim=['2020-01-01','2021-09-01'],ylim=[0,900],figsize=(12,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
## xlimit and y limit and coloring
df_tesla['High'].plot(xlim=['2020-01-01','2021-09-01'],ylim=[0,900],figsize=(12,4),ls='--',c='green')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tesla.index
# Out:
# DatetimeIndex(['2017-02-01', '2017-02-02', '2017-02-03', '2017-02-06',
#                '2017-02-07', '2017-02-08', '2017-02-09', '2017-02-10',
#                '2017-02-13', '2017-02-14',
#                ...
#                '2022-02-09', '2022-02-10', '2022-02-11', '2022-02-14',
#                '2022-02-15', '2022-02-16', '2022-02-17', '2022-02-18',
#                '2022-02-22', '2022-02-23'],
#               dtype='datetime64[ns]', name='Date', length=1275, freq=None)

# %%
index=df_tesla.loc['2020-01-01':'2021-09-01'].index
share_open=df_tesla.loc['2020-01-01':'2021-09-01']['Open']

# %%
share_open
# Out:
# Date
# 2020-01-02     28.299999
# 2020-01-03     29.366667
# 2020-01-06     29.364668
# 2020-01-07     30.760000
# 2020-01-08     31.580000
#                  ...
# 2021-08-26    236.103333
# 2021-08-27    235.000000
# 2021-08-30    238.240005
# 2021-08-31    244.333328
# 2021-09-01    244.693329
# Name: Open, Length: 421, dtype: float64

# %%
index
# Out:
# DatetimeIndex(['2020-01-02', '2020-01-03', '2020-01-06', '2020-01-07',
#                '2020-01-08', '2020-01-09', '2020-01-10', '2020-01-13',
#                '2020-01-14', '2020-01-15',
#                ...
#                '2021-08-19', '2021-08-20', '2021-08-23', '2021-08-24',
#                '2021-08-25', '2021-08-26', '2021-08-27', '2021-08-30',
#                '2021-08-31', '2021-09-01'],
#               dtype='datetime64[ns]', name='Date', length=421, freq=None)

# %% [markdown]
# #### Plot Preventing overlapping

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
figure,axis=plt.subplots()
axis.plot(index,share_open)

# %%
figure,axis=plt.subplots()
plt.tight_layout()
axis.plot(index,share_open)

# %%
## Preventing overlapping

figure,axis=plt.subplots()
plt.tight_layout()

figure.autofmt_xdate()
axis.plot(index,share_open)

# %%
## Datetime  Index

# %%
df_tesla=df_tesla.reset_index()

# %%
df_tesla.head()
# Out:
#         Date       Open       High        Low      Close  Adj Close    Volume
# 0 2017-02-01  16.870001  16.879999  16.603333  16.615999  16.615999  59382000
# 1 2017-02-02  16.556000  16.827999  16.514000  16.770000  16.770000  37497000
# 2 2017-02-03  16.794001  16.812000  16.645332  16.755333  16.755333  32800500
# 3 2017-02-06  16.733334  17.188000  16.708668  17.184668  17.184668  53437500
# 4 2017-02-07  17.212667  17.333332  17.094667  17.165333  17.165333  63672000

# %%
df_tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1275 entries, 0 to 1274
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1275 non-null   datetime64[ns]
#  1   Open       1275 non-null   float64
#  2   High       1275 non-null   float64
#  3   Low        1275 non-null   float64
#  4   Close      1275 non-null   float64
#  5   Adj Close  1275 non-null   float64
#  6   Volume     1275 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 69.9 KB

# %%
df_tesla=df_tesla.set_index('Date',drop=True)

# %%
df_tesla.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2017-02-01  16.870001  16.879999  16.603333  16.615999  16.615999  59382000
# 2017-02-02  16.556000  16.827999  16.514000  16.770000  16.770000  37497000
# 2017-02-03  16.794001  16.812000  16.645332  16.755333  16.755333  32800500
# 2017-02-06  16.733334  17.188000  16.708668  17.184668  17.184668  53437500
# 2017-02-07  17.212667  17.333332  17.094667  17.165333  17.165333  63672000

# %%
## datetime
from datetime import datetime

# %%
datetime(2021,11,21)
# Out:
# datetime.datetime(2021, 11, 21, 0, 0)

# %%
datetime.now()
# Out:
# datetime.datetime(2023, 12, 19, 11, 26, 30, 177772)

# %%
date=datetime(2021,11,21)

# %%
date
# Out:
# datetime.datetime(2021, 11, 21, 0, 0)

# %%
date.date()
# Out:
# datetime.date(2021, 11, 21)

# %%
date.day
# Out:
# 21

# %%
date.weekday()
# Out:
# 6

# %%
date.year
# Out:
# 2021

# %%
date.month
# Out:
# 11

# %% [markdown]
# ## Time Resampling

# %%
df_tesla.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2017-02-01  16.870001  16.879999  16.603333  16.615999  16.615999  59382000
# 2017-02-02  16.556000  16.827999  16.514000  16.770000  16.770000  37497000
# 2017-02-03  16.794001  16.812000  16.645332  16.755333  16.755333  32800500
# 2017-02-06  16.733334  17.188000  16.708668  17.184668  17.184668  53437500
# 2017-02-07  17.212667  17.333332  17.094667  17.165333  17.165333  63672000

# %%
## A = year end frequency
df_tesla.resample(rule='A').min()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-12-31   16.279333   16.433332   16.134001   16.246000   16.246000
# 2018-12-31   16.851999   17.355333   16.306000   16.704000   16.704000
# 2019-12-31   12.073333   12.445333   11.799333   11.931333   11.931333
# 2020-12-31   24.980000   26.990667   23.367332   24.081333   24.081333
# 2021-12-31  184.183334  188.736664  179.830002  187.666672  187.666672
# 2022-12-31  276.809998  278.433319  253.520004  254.679993  254.679993
#
#               Volume
# Date
# 2017-12-31  32800500
# 2018-12-31  46210500
# 2019-12-31  36984000
# 2020-12-31  52073100
# 2021-12-31  29401800
# 2022-12-31  50729100

# %%
df_tesla.resample(rule='A').max()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-12-31   25.779333   25.974001   25.290001   25.666668   25.666668
# 2018-12-31   25.000000   25.830667   24.474667   25.304667   25.304667
# 2019-12-31   29.000000   29.020666   28.423332   28.729334   28.729334
# 2020-12-31  233.330002  239.573334  230.373337  235.223328  235.223328
# 2021-12-31  411.470001  414.496674  405.666656  409.970001  409.970001
# 2022-12-31  396.516663  402.666656  378.679993  399.926666  399.926666
#
#                Volume
# Date
# 2017-12-31  296871000
# 2018-12-31  504745500
# 2019-12-31  450091500
# 2020-12-31  914082000
# 2021-12-31  268189500
# 2022-12-31  151565700

# %%
## A = year end frequency
df_tesla.resample(rule='A').max()['Open'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
### Qs = quaterly start frequency
df_tesla.resample(rule='QS').max()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-01-01   18.687332   19.159332   18.573999   18.732000   18.732000
# 2017-04-01   25.779333   25.799334   25.290001   25.563334   25.563334
# 2017-07-01   25.350000   25.974001   25.178667   25.666668   25.666668
# 2017-10-01   23.798668   24.200001   23.608667   23.976667   23.976667
# 2018-01-01   24.000000   24.033333   23.490667   23.827999   23.827999
# 2018-04-01   24.344000   24.915333   23.633333   24.722000   24.722000
# 2018-07-01   24.606001   25.830667   24.474667   25.304667   25.304667
# 2018-10-01   25.000000   25.299334   24.450001   25.119333   25.119333
# 2019-01-01   23.080667   23.466667   22.943333   23.153999   23.153999
# 2019-04-01   19.219999   19.744667   19.144667   19.454000   19.454000
# 2019-07-01   17.278000   17.738001   17.210667   17.658667   17.658667
# 2019-10-01   29.000000   29.020666   28.423332   28.729334   28.729334
# ...

# %%
##https://towardsdatascience.com/resample-function-of-pandas-79b17ec82a78
df_tesla.resample(rule='QS').max()['High'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
### Qs = quaterly end frequency
df_tesla.resample(rule='Q').max()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-03-31   18.687332   19.159332   18.573999   18.732000   18.732000
# 2017-06-30   25.779333   25.799334   25.290001   25.563334   25.563334
# 2017-09-30   25.350000   25.974001   25.178667   25.666668   25.666668
# 2017-12-31   23.798668   24.200001   23.608667   23.976667   23.976667
# 2018-03-31   24.000000   24.033333   23.490667   23.827999   23.827999
# 2018-06-30   24.344000   24.915333   23.633333   24.722000   24.722000
# 2018-09-30   24.606001   25.830667   24.474667   25.304667   25.304667
# 2018-12-31   25.000000   25.299334   24.450001   25.119333   25.119333
# 2019-03-31   23.080667   23.466667   22.943333   23.153999   23.153999
# 2019-06-30   19.219999   19.744667   19.144667   19.454000   19.454000
# 2019-09-30   17.278000   17.738001   17.210667   17.658667   17.658667
# 2019-12-31   29.000000   29.020666   28.423332   28.729334   28.729334
# ...

# %%
## BA = Business End Frequency
##https://towardsdatascience.com/resample-function-of-pandas-79b17ec82a78
df_tesla.resample(rule='BA').max()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-12-29   25.779333   25.974001   25.290001   25.666668   25.666668
# 2018-12-31   25.000000   25.830667   24.474667   25.304667   25.304667
# 2019-12-31   29.000000   29.020666   28.423332   28.729334   28.729334
# 2020-12-31  233.330002  239.573334  230.373337  235.223328  235.223328
# 2021-12-31  411.470001  414.496674  405.666656  409.970001  409.970001
# 2022-12-30  396.516663  402.666656  378.679993  399.926666  399.926666
#
#                Volume
# Date
# 2017-12-29  296871000
# 2018-12-31  504745500
# 2019-12-31  450091500
# 2020-12-31  914082000
# 2021-12-31  268189500
# 2022-12-30  151565700

# %%
## BQS = Business Quarter Starting 
df_tesla.resample(rule='BQS').max()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-01-02   18.687332   19.159332   18.573999   18.732000   18.732000
# 2017-04-03   25.779333   25.799334   25.290001   25.563334   25.563334
# 2017-07-03   25.350000   25.974001   25.178667   25.666668   25.666668
# 2017-10-02   23.798668   24.200001   23.608667   23.976667   23.976667
# 2018-01-01   24.000000   24.033333   23.490667   23.827999   23.827999
# 2018-04-02   24.344000   24.915333   23.633333   24.722000   24.722000
# 2018-07-02   24.606001   25.830667   24.474667   25.304667   25.304667
# 2018-10-01   25.000000   25.299334   24.450001   25.119333   25.119333
# 2019-01-01   23.080667   23.466667   22.943333   23.153999   23.153999
# 2019-04-01   19.219999   19.744667   19.144667   19.454000   19.454000
# 2019-07-01   17.278000   17.738001   17.210667   17.658667   17.658667
# 2019-10-01   29.000000   29.020666   28.423332   28.729334   28.729334
# ...

# %%
## BQS = Business Quarter Ending
df_tesla.resample(rule='BQ').max()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-03-31   18.687332   19.159332   18.573999   18.732000   18.732000
# 2017-06-30   25.779333   25.799334   25.290001   25.563334   25.563334
# 2017-09-29   25.350000   25.974001   25.178667   25.666668   25.666668
# 2017-12-29   23.798668   24.200001   23.608667   23.976667   23.976667
# 2018-03-30   24.000000   24.033333   23.490667   23.827999   23.827999
# 2018-06-29   24.344000   24.915333   23.633333   24.722000   24.722000
# 2018-09-28   24.606001   25.830667   24.474667   25.304667   25.304667
# 2018-12-31   25.000000   25.299334   24.450001   25.119333   25.119333
# 2019-03-29   23.080667   23.466667   22.943333   23.153999   23.153999
# 2019-06-28   19.219999   19.744667   19.144667   19.454000   19.454000
# 2019-09-30   17.278000   17.738001   17.210667   17.658667   17.658667
# 2019-12-31   29.000000   29.020666   28.423332   28.729334   28.729334
# ...

# %%
##plotting
df_tesla['Open'].resample(rule='A').mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tesla['Open'].resample(rule='M').max().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tesla['Open'].resample(rule='M').max().plot(kind='bar',figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Rolling

# %%
df_tesla['High'].head(10)
# Out:
# Date
# 2017-02-01    16.879999
# 2017-02-02    16.827999
# 2017-02-03    16.812000
# 2017-02-06    17.188000
# 2017-02-07    17.333332
# 2017-02-08    17.557333
# 2017-02-09    18.078667
# 2017-02-10    18.063334
# 2017-02-13    18.719334
# 2017-02-14    19.159332
# Name: High, dtype: float64

# %%
df_tesla['High'].rolling(2).max().head(20)
# Out:
# Date
# 2017-02-01          NaN
# 2017-02-02    16.879999
# 2017-02-03    16.827999
# 2017-02-06    17.188000
# 2017-02-07    17.333332
# 2017-02-08    17.557333
# 2017-02-09    18.078667
# 2017-02-10    18.078667
# 2017-02-13    18.719334
# 2017-02-14    19.159332
# 2017-02-15    19.159332
# 2017-02-16    18.816000
# 2017-02-17    18.666668
# 2017-02-21    18.760000
# 2017-02-22    18.896667
# 2017-02-23    18.896667
# 2017-02-24    17.643999
# 2017-02-27    17.216667
# 2017-02-28    16.733334
# 2017-03-01    16.990000
# Name: High, dtype: float64

# %%
df_tesla['High'].rolling(10).max().head(20)
# Out:
# Date
# 2017-02-01          NaN
# 2017-02-02          NaN
# 2017-02-03          NaN
# 2017-02-06          NaN
# 2017-02-07          NaN
# 2017-02-08          NaN
# 2017-02-09          NaN
# 2017-02-10          NaN
# 2017-02-13          NaN
# 2017-02-14    19.159332
# 2017-02-15    19.159332
# 2017-02-16    19.159332
# 2017-02-17    19.159332
# 2017-02-21    19.159332
# 2017-02-22    19.159332
# 2017-02-23    19.159332
# 2017-02-24    19.159332
# 2017-02-27    19.159332
# 2017-02-28    19.159332
# 2017-03-01    18.896667
# Name: High, dtype: float64

# %%
df_tesla.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2017-02-01  16.870001  16.879999  16.603333  16.615999  16.615999  59382000
# 2017-02-02  16.556000  16.827999  16.514000  16.770000  16.770000  37497000
# 2017-02-03  16.794001  16.812000  16.645332  16.755333  16.755333  32800500
# 2017-02-06  16.733334  17.188000  16.708668  17.184668  17.184668  53437500
# 2017-02-07  17.212667  17.333332  17.094667  17.165333  17.165333  63672000
#
#             Open:30 days rolling
# Date
# 2017-02-01                   NaN
# 2017-02-02                   NaN
# 2017-02-03                   NaN
# 2017-02-06                   NaN
# 2017-02-07                   NaN

# %%
df_tesla['Open:30 days rolling']=df_tesla['Open'].rolling(30).mean()

# %%
df_tesla.head(31)
# Out:
#                  Open       High        Low      Close  Adj Close     Volume  \
# Date
# 2017-02-01  16.870001  16.879999  16.603333  16.615999  16.615999   59382000
# 2017-02-02  16.556000  16.827999  16.514000  16.770000  16.770000   37497000
# 2017-02-03  16.794001  16.812000  16.645332  16.755333  16.755333   32800500
# 2017-02-06  16.733334  17.188000  16.708668  17.184668  17.184668   53437500
# 2017-02-07  17.212667  17.333332  17.094667  17.165333  17.165333   63672000
# 2017-02-08  17.156668  17.557333  17.080000  17.472000  17.472000   58995000
# 2017-02-09  17.750000  18.078667  17.743334  17.946667  17.946667  117303000
# 2017-02-10  17.986000  18.063334  17.740667  17.948668  17.948668   54295500
# 2017-02-13  18.049334  18.719334  18.034000  18.706667  18.706667  105444000
# 2017-02-14  18.601999  19.159332  18.573999  18.732000  18.732000  110178000
# 2017-02-15  18.666668  18.816000  18.429333  18.650667  18.650667   74218500
# ...

# %%
df_tesla[['Open','Open:30 days rolling']].plot(figsize=(12,5))
# Out:
# <AxesSubplot:xlabel='Date'>
